# %% [markdown]
# <a href="https://colab.research.google.com/github/TrongAnh2210/AI_Homework/blob/main/Homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#Khai báo thư viện

#1.Thư viện tính toán và hiển thị 
import matplotlib.pyplot as plt
import numpy as np

#2.Thư viện xử lý hình 3 chiều thành dữ liệu dưới dạng số
from os import listdir
from numpy import asarray, save
from keras.utils import load_img
from keras.utils import img_to_array
from keras.utils import to_categorical

# %%
folder = '/content/gdrive/MyDrive/VND'
photos, labels = list(), list()
# Load and preprocess the data
photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if  file.startswith('100k'):
        output = 1.0
  elif file.startswith('10k'):
        output = 2.0
  elif file.startswith('200k'):
        output = 3.0
  elif file.startswith('20k'):
        output = 4.0
  elif file.startswith('500k'):
        output = 5.0
  elif file.startswith('50k'):
        output = 6.0
  photo = load_img(folder + '/' + file, target_size= (30,40,3))
  photo= img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos= asarray(photos)
labels= asarray(labels)
print(photos.shape, labels.shape)

save('/content/gdrive/MyDrive/result_VND/VND_photos.npy', photos)
save('/content/gdrive/MyDrive/result_VND/VND_labels.npy', labels)
# Out:
# (702, 30, 40, 3) (702,)

# %%
# Khởi tạo và sử dụng dữ liệu đã tạo
photos = np.load('/content/gdrive/MyDrive/result_VND/VND_photos.npy')
labels = np.load('/content/gdrive/MyDrive/result_VND/VND_labels.npy')

# Preprocess data
photos = photos.astype('float32') / 255.0
labels = to_categorical(labels)
print(photos.shape, labels.shape)
# Chia ra thành 2 phần để test và train

test_x, test_y = photos[:7], labels[:7]
train_x, train_y = photos[7:], labels[7:]
# Out:
# (702, 30, 40, 3) (702, 7)

# %%
from keras.models import Sequential,Model
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Normalization
from keras.layers.activation import LeakyReLU
from keras.optimizers import Adam
from keras import losses
from keras.losses import categorical_crossentropy

# %%
# Tạo ra mô hình mạng CNN để train

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(30, 40, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, kernel_size= (3,3), activation= 'relu', padding= 'same'))
model.add(Conv2D(64, kernel_size= (3,3), activation= 'relu', padding= 'same'))
model.add(MaxPooling2D((2,2), padding= 'same'))

model.add(Conv2D(128, kernel_size= (3,3), activation= 'relu', padding= 'same'))
model.add(Conv2D(128, kernel_size= (3,3), activation= 'relu', padding= 'same'))
model.add(MaxPooling2D((2,2), padding= 'same'))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 38, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 14, 19, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 12, 17, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 8, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 8, 64)          36928
#
#  conv2d_3 (Conv2D)           (None, 6, 8, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 4, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 3, 4, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 3, 4, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 381,255
# Trainable params: 381,255
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Biên dịch chương trình
from keras.backend import categorical_crossentropy
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Augment data with ImageDataGenerator
datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1, shear_range=0.2, zoom_range=0.2, horizontal_flip=True,fill_mode='nearest')

datagen.fit(train_x)

# Train model
history = model.fit(datagen.flow(train_x, train_y, batch_size=20), epochs=30, validation_data=(test_x, test_y))

# Evaluate model
test_loss, test_acc = model.evaluate(test_x, test_y) 
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/30
# 35/35 [==============================] - 6s 114ms/step - loss: 0.7693 - accuracy: 0.7108 - val_loss: 0.2712 - val_accuracy: 0.8571
# Epoch 2/30
# 35/35 [==============================] - 3s 75ms/step - loss: 0.5387 - accuracy: 0.7827 - val_loss: 0.4297 - val_accuracy: 0.8571
# Epoch 3/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.6604 - accuracy: 0.7784 - val_loss: 0.1586 - val_accuracy: 1.0000
# Epoch 4/30
# 35/35 [==============================] - 3s 73ms/step - loss: 0.5837 - accuracy: 0.7856 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 5/30
# 35/35 [==============================] - 3s 75ms/step - loss: 0.5424 - accuracy: 0.7942 - val_loss: 0.1784 - val_accuracy: 1.0000
# Epoch 6/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.4243 - accuracy: 0.8547 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 7/30
# 35/35 [==============================] - 3s 73ms/step - loss: 0.4577 - accuracy: 0.8187 - val_loss: 0.1840 - val_accuracy: 0.8571
# Epoch 8/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.4221 - accuracy: 0.8446 - val_loss: 0.3158 - val_accuracy: 0.8571
# Epoch 9/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.4251 - accuracy: 0.8576 - val_loss: 0.1168 - val_accuracy: 1.0000
# Epoch 10/30
# 35/35 [==============================] - 3s 76ms/step - loss: 0.3737 - accuracy: 0.8647 - val_loss: 0.0598 - val_accuracy: 1.0000
# Epoch 11/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.3367 - accuracy: 0.8849 - val_loss: 0.2082 - val_accuracy: 0.8571
# Epoch 12/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.3969 - accuracy: 0.8475 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 13/30
# 35/35 [==============================] - 3s 76ms/step - loss: 0.3505 - accuracy: 0.8604 - val_loss: 0.3449 - val_accuracy: 0.8571
# Epoch 14/30
# 35/35 [==============================] - 4s 124ms/step - loss: 0.4166 - accuracy: 0.8547 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 15/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.3005 - accuracy: 0.8978 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 16/30
# 35/35 [==============================] - 3s 74ms/step - loss: 0.2712 - accuracy: 0.9094 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 17/30
# 35/35 [==============================] - 3s 88ms/step - loss: 0.2998 - accuracy: 0.8964 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 18/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2702 - accuracy: 0.8993 - val_loss: 0.3365 - val_accuracy: 0.8571
# Epoch 19/30
# 35/35 [==============================] - 2s 71ms/step - loss: 0.2623 - accuracy: 0.9065 - val_loss: 0.6828 - val_accuracy: 0.8571
# Epoch 20/30
# 35/35 [==============================] - 3s 73ms/step - loss: 0.2551 - accuracy: 0.9094 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 21/30
# 35/35 [==============================] - 4s 126ms/step - loss: 0.2838 - accuracy: 0.8935 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 22/30
# 35/35 [==============================] - 3s 71ms/step - loss: 0.4096 - accuracy: 0.8446 - val_loss: 0.2043 - val_accuracy: 1.0000
# Epoch 23/30
# 35/35 [==============================] - 3s 71ms/step - loss: 0.2213 - accuracy: 0.9281 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 24/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2372 - accuracy: 0.9209 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 25/30
# 35/35 [==============================] - 4s 109ms/step - loss: 0.2668 - accuracy: 0.9108 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 26/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1574 - accuracy: 0.9396 - val_loss: 0.1541 - val_accuracy: 0.8571
# Epoch 27/30
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1888 - accuracy: 0.9367 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 28/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2323 - accuracy: 0.9223 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 29/30
# 35/35 [==============================] - 3s 81ms/step - loss: 0.2051 - accuracy: 0.9367 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 30/30
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2318 - accuracy: 0.9209 - val_loss: 0.0105 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0105 - accuracy: 1.0000
# Test accuracy: 1.0

# %%
import matplotlib.pyplot as plt
eval = model.evaluate(test_x, test_y, verbose=0)
print('Test loss:', eval[0])
print('Test accunacy', eval[1])
accuracy = history.history['accuracy']
loss = history.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy,'bo', label = 'Traning Accuracy')
plt.plot(epochs, loss, 'b', label= 'Test Accuracy')
plt.title('Training & Testing Accuracy')
# Out:
# Test loss: 0.010536215268075466
# Test accunacy 1.0
# Text(0.5, 1.0, 'Training & Testing Accuracy')

# %%
#Testing
from os import listdir
from keras.utils import load_img
from keras.utils.image_utils import img_to_array

folder = '/content/gdrive/MyDrive/VND_test'
for file in listdir(folder):
  photo = load_img(folder + '/' +  file)
  plt.imshow(photo)
  photo = load_img(folder + '/' +  file, target_size = (30, 40))
  photo=img_to_array(photo)
  photo=photo.astype('float32')
  photo=photo/255
  photo=np.expand_dims(photo,axis=0)
  result=(model.predict(photo).argmax())
  
  class_name=[' ','100k', '10k', '200k', '20k', '500k','50k']
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 50k
# 1/1 [==============================] - 0s 22ms/step
# 500k
# 1/1 [==============================] - 0s 25ms/step
# 20k
# 1/1 [==============================] - 0s 25ms/step
# 10k
# 1/1 [==============================] - 0s 22ms/step
# 200k
# 1/1 [==============================] - 0s 23ms/step
# 100k
